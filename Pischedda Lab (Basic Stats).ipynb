# %%
import pandas as pd
import numpy as np

# %%
juv = pd.read_excel('MMC Juv.xlsx', sheet_name = 'Juvenile')

# %%
juv
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 0  2024-06-11    L1           L        7       15          62         58
# 1  2024-06-11   L10           L       10       16          66         71
# 2  2024-06-11    L2           L       14       12          65         62
# 3  2024-06-11    L3           L       15       10          49         50
# 4  2024-06-11    L4           L       14       10          73         69
# ..        ...   ...         ...      ...      ...         ...        ...
# 95 2024-09-17    S5           S       14       11          56         67
# 96 2024-09-17    S2           S       14       11          64         71
# 97 2024-09-17    S3           S        9       13          60         65
# 98 2024-09-17    S1           S       15       14          60         61
# 99 2024-09-17   S10           S       11       14          67         65
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# ...

# %%
juv.head()
# Out:
#         Date Label Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 0 2024-06-11    L1           L        7       15          62         58
# 1 2024-06-11   L10           L       10       16          66         71
# 2 2024-06-11    L2           L       14       12          65         62
# 3 2024-06-11    L3           L       15       10          49         50
# 4 2024-06-11    L4           L       14       10          73         69
#
#    Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# 0         22          120                    142               0.733333
# 1         26          137                    163               0.866667
# 2         26          127                    153               0.866667
# 3         25           99                    124               0.833333
# 4         24          142                    166               0.800000

# %%
juv.tail()
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 95 2024-09-17    S5           S       14       11          56         67
# 96 2024-09-17    S2           S       14       11          64         71
# 97 2024-09-17    S3           S        9       13          60         65
# 98 2024-09-17    S1           S       15       14          60         61
# 99 2024-09-17   S10           S       11       14          67         65
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# 95         25          123                    148               0.833333
# 96         25          135                    160               0.833333
# 97         22          125                    147               0.733333
# 98         29          121                    150               0.966667
# 99         25          132                    157               0.833333

# %%
juv.dropna()
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 0  2024-06-11    L1           L        7       15          62         58
# 1  2024-06-11   L10           L       10       16          66         71
# 2  2024-06-11    L2           L       14       12          65         62
# 3  2024-06-11    L3           L       15       10          49         50
# 4  2024-06-11    L4           L       14       10          73         69
# ..        ...   ...         ...      ...      ...         ...        ...
# 95 2024-09-17    S5           S       14       11          56         67
# 96 2024-09-17    S2           S       14       11          64         71
# 97 2024-09-17    S3           S        9       13          60         65
# 98 2024-09-17    S1           S       15       14          60         61
# 99 2024-09-17   S10           S       11       14          67         65
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# ...

# %%
juv.isnull()
# Out:
#      Date  Label  Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 0   False  False        False    False    False       False      False
# 1   False  False        False    False    False       False      False
# 2   False  False        False    False    False       False      False
# 3   False  False        False    False    False       False      False
# 4   False  False        False    False    False       False      False
# ..    ...    ...          ...      ...      ...         ...        ...
# 95  False  False        False    False    False       False      False
# 96  False  False        False    False    False       False      False
# 97  False  False        False    False    False       False      False
# 98  False  False        False    False    False       False      False
# 99  False  False        False    False    False       False      False
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# ...

# %%
juv.groupby('Female Size')['Red Juvenile Survival'].mean()
# Out:
# Female Size
# L    0.832
# S    0.878
# Name: Red Juvenile Survival, dtype: float64

# %%
juv.groupby('Female Size')['Red Juvenile Survival'].median()
# Out:
# Female Size
# L    0.850000
# S    0.866667
# Name: Red Juvenile Survival, dtype: float64

# %%
juv.groupby('Female Size')['Red Juvenile Survival'].std()
# Out:
# Female Size
# L    0.081360
# S    0.088988
# Name: Red Juvenile Survival, dtype: float64

# %%
juv.columns = juv.columns.str.strip()
juv['Total Females'] = juv['# Red F'] + juv['# Brown F']

# %%
juv
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F  # Brown M  \
# 0  2024-06-11    L1           L        7       15         62         58
# 1  2024-06-11   L10           L       10       16         66         71
# 2  2024-06-11    L2           L       14       12         65         62
# 3  2024-06-11    L3           L       15       10         49         50
# 4  2024-06-11    L4           L       14       10         73         69
# ..        ...   ...         ...      ...      ...        ...        ...
# 95 2024-09-17    S5           S       14       11         56         67
# 96 2024-09-17    S2           S       14       11         64         71
# 97 2024-09-17    S3           S        9       13         60         65
# 98 2024-09-17    S1           S       15       14         60         61
# 99 2024-09-17   S10           S       11       14         67         65
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival  \
# ...

# %%
juv.columns = juv.columns.str.strip()
juv['Total Females'] = juv['# Red M'] + juv['# Brown M']

# %%
juv
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F  # Brown M  \
# 0  2024-06-11    L1           L        7       15         62         58
# 1  2024-06-11   L10           L       10       16         66         71
# 2  2024-06-11    L2           L       14       12         65         62
# 3  2024-06-11    L3           L       15       10         49         50
# 4  2024-06-11    L4           L       14       10         73         69
# ..        ...   ...         ...      ...      ...        ...        ...
# 95 2024-09-17    S5           S       14       11         56         67
# 96 2024-09-17    S2           S       14       11         64         71
# 97 2024-09-17    S3           S        9       13         60         65
# 98 2024-09-17    S1           S       15       14         60         61
# 99 2024-09-17   S10           S       11       14         67         65
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival  \
# ...

# %%
juv.drop('Label', axis = 1, inplace = True)

# %%
juv
# Out:
#          Date Female Size  # Red F  # Red M  # Brown F  # Brown M  Total Red  \
# 0  2024-06-11           L        7       15         62         58         22
# 1  2024-06-11           L       10       16         66         71         26
# 2  2024-06-11           L       14       12         65         62         26
# 3  2024-06-11           L       15       10         49         50         25
# 4  2024-06-11           L       14       10         73         69         24
# ..        ...         ...      ...      ...        ...        ...        ...
# 95 2024-09-17           S       14       11         56         67         25
# 96 2024-09-17           S       14       11         64         71         25
# 97 2024-09-17           S        9       13         60         65         22
# 98 2024-09-17           S       15       14         60         61         29
# 99 2024-09-17           S       11       14         67         65         25
#
# ...

# %%
juv2 = juv[juv['Total Number of Flies'] > 150]

# %%
juv2.groupby('Female Size')['Red Juvenile Survival'].mean()
# Out:
# Female Size
# L    0.840625
# S    0.881982
# Name: Red Juvenile Survival, dtype: float64

# %%
juv2.describe().round(2)
# Out:
#                                 Date  # Red F  # Red M  # Brown F  # Brown M  \
# count                             69    69.00    69.00      69.00      69.00
# mean   2024-07-15 04:52:10.434782720    12.49    13.39      66.59      66.22
# min              2024-06-11 00:00:00     7.00     7.00      56.00      49.00
# 25%              2024-06-24 00:00:00    11.00    12.00      62.00      63.00
# 50%              2024-07-09 00:00:00    13.00    13.00      66.00      67.00
# 75%              2024-07-22 00:00:00    14.00    15.00      72.00      70.00
# max              2024-09-17 00:00:00    20.00    19.00      78.00      80.00
# std                              NaN     2.42     2.54       5.97       6.11
#
#        Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival  \
# count      69.00        69.00                  69.00                  69.00
# mean       25.88       132.81                 158.70                   0.86
# ...

# %%
juv_cleaned = juv[juv['Red Juvenile Survival'] < 1]

# %%
juv_cleaned
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 0  2024-06-11    L1           L        7       15          62         58
# 1  2024-06-11   L10           L       10       16          66         71
# 2  2024-06-11    L2           L       14       12          65         62
# 3  2024-06-11    L3           L       15       10          49         50
# 4  2024-06-11    L4           L       14       10          73         69
# ..        ...   ...         ...      ...      ...         ...        ...
# 95 2024-09-17    S5           S       14       11          56         67
# 96 2024-09-17    S2           S       14       11          64         71
# 97 2024-09-17    S3           S        9       13          60         65
# 98 2024-09-17    S1           S       15       14          60         61
# 99 2024-09-17   S10           S       11       14          67         65
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# ...

# %%
juv_cleaned.isnull().sum()
# Out:
# Date                     0
# Label                    0
# Female Size              0
# # Red F                  0
# # Red M                  0
# # Brown F                0
# # Brown M                0
# Total Red                0
# Total Brown              0
# Total Number of Flies    0
# Red Juvenile Survival    0
# dtype: int64

# %%
juv[juv['Total Red'] > juv['Total Brown']]
# Out:
# Empty DataFrame
# Columns: [Date, Label, Female Size, # Red F, # Red M, # Brown F , # Brown M, Total Red, Total Brown, Total Number of Flies, Red Juvenile Survival]
# Index: []

# %%
juv2.groupby('Female Size')[['Red Juvenile Survival', 'Total Number of Flies']].mean()
# Out:
#              Red Juvenile Survival  Total Number of Flies
# Female Size
# L                         0.840625             158.375000
# S                         0.881982             158.972973

# %%
juv_cleaned.sort_values(by = 'Red Juvenile Survival', ascending = False)
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 86 2024-09-17    L1           L       15       14          59         65
# 30 2024-06-24   S10           S       14       15          59         65
# 52 2024-07-09    S2           S       13       16          66         53
# 91 2024-09-17    S9           S       12       17          66         61
# 98 2024-09-17    S1           S       15       14          60         61
# ..        ...   ...         ...      ...      ...         ...        ...
# 32 2024-06-24    L8           L       10       11          72         63
# 36 2024-06-24    L1           L        8       13          62         69
# 57 2024-07-09    S7           S        9       11          67         55
# 47 2024-07-09    L7           L        9       10          66         69
# 40 2024-07-09    L1           L       11        8          68         50
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# ...

# %%
juv_cleaned.drop_duplicates().head
# Out:
#          Date Label Female Size  # Red F  # Red M  # Brown F   # Brown M  \
# 0  2024-06-11    L1           L        7       15          62         58
# 1  2024-06-11   L10           L       10       16          66         71
# 2  2024-06-11    L2           L       14       12          65         62
# 3  2024-06-11    L3           L       15       10          49         50
# 4  2024-06-11    L4           L       14       10          73         69
# ..        ...   ...         ...      ...      ...         ...        ...
# 95 2024-09-17    S5           S       14       11          56         67
# 96 2024-09-17    S2           S       14       11          64         71
# 97 2024-09-17    S3           S        9       13          60         65
# 98 2024-09-17    S1           S       15       14          60         61
# 99 2024-09-17   S10           S       11       14          67         65
#
#     Total Red  Total Brown  Total Number of Flies  Red Juvenile Survival
# ...

# %%
juv_cleaned['Female Size'].value_counts()
# Out:
# Female Size
# L    50
# S    47
# Name: count, dtype: int64

# %%
juv_cleaned.pivot_table(values='Total Number of Flies', index='Female Size', columns='Label').fillna('No Sample')
# Out:
# Label               L1        L10         L2         L3         L4         L5  \
# Female Size
# L                146.2      158.8      153.2      143.8      157.4      153.2
# S            No Sample  No Sample  No Sample  No Sample  No Sample  No Sample
#
# Label               L6         L7         L8         L9         S1        S10  \
# Female Size
# L                154.8      154.6      150.6      155.0  No Sample  No Sample
# S            No Sample  No Sample  No Sample  No Sample      157.0      158.0
#
# Label               S2         S3         S4         S5         S6         S7  \
# Female Size
# L            No Sample  No Sample  No Sample  No Sample  No Sample  No Sample
# S                153.2      153.2      155.4      158.6     152.75      154.0
#
# Label               S8         S9
# Female Size
# L            No Sample  No Sample
# S                152.0      160.2
